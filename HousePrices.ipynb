# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
pd.set_option('display.max_columns', None)

# %%
test = pd.read_csv("test.csv")
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train = pd.read_csv("train.csv")
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
naColTr = train.isna().sum()
naColTr[naColTr.isin([0]) == False]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
all_data = pd.concat([test, train])
all_data = all_data.drop("Id", axis=1)
all_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler


all_data["MSSubClass"] = all_data["MSSubClass"].astype('category').cat.codes

# t = all_data["LotFrontage"].fillna(69)
# t = stats.boxcox(t)[0]
# t = np.array(t).reshape(-1, 1)
# mms = MinMaxScaler()
# t = mms.fit_transform(t)
# t = pd.Series(t.reshape(2919)) shit

all_data["LotFrontage"] = t

# %%
all_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0              0       RH    18.237403    11622   Pave   NaN      Reg
# 1              0       RL    18.374108    14267   Pave   NaN      IR1
# 2              5       RL    17.400332    13830   Pave   NaN      IR1
# 3              5       RL    17.961646     9978   Pave   NaN      IR1
# 4             11       RL    12.463435     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455           5       RL    15.627893     7917   Pave   NaN      Reg
# 1456           0       RL    18.913431    13175   Pave   NaN      Reg
# 1457           6       RL    16.234718     9042   Pave   NaN      Reg
# 1458           0       RL    16.531868     9717   Pave   NaN      Reg
# 1459           0       RL    17.541924     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
all_data.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage         0
# LotArea             0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 81, dtype: int64

# %%
train["LotFrontage"].isna().sum()
# Out:
# 259

# %%
test["LotFrontage"].isna().sum()
# Out:
# 227

# %%
sns.histplot(all_data["LotFrontage"], kde=True)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='Count'>

# %%
all_data["LotFrontage"].mean()
t = all_data["LotFrontage"].fillna(69)
t
# Out:
# 0       80.0
# 1       81.0
# 2       74.0
# 3       78.0
# 4       43.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 2919, dtype: float64

# %%
normalized_data = stats.boxcox(t)
normalized_data = pd.Series(normalized_data[0], name="LotFrontage")
sns.histplot(normalized_data, kde=True,)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='Count'>

# %%
s = np.array(all_data["LotFrontage"]).reshape(-1, 1)
mms = MinMaxScaler()
k = mms.fit_transform(s)
k = pd.Series(k.reshape(2919))
sns.histplot(k, kde=True,)
# Out:
# <Axes: ylabel='Count'>

# %%
X = pd.DataFrame(all_data["MSSubClass"])
X["LotFrontage"] = normalized_data
X == all_data[["MSSubClass", "LotFrontage"]]
# Out:
#       MSSubClass  LotFrontage
# 0           True         True
# 1           True         True
# 2           True         True
# 3           True         True
# 4           True         True
# ...          ...          ...
# 1455        True        False
# 1456        True        False
# 1457        True        False
# 1458        True        False
# 1459        True        False
#
# [2919 rows x 2 columns]

# %%
x_min = all_data["LotFrontage"].min
x_max = all_data["LotFrontage"].max
x_std = all_data["LotFrontage"].std
# Out:
# array([[0.31888227],
#        [0.32307142],
#        [0.2932314 ],
#        ...,
#        [0.2575128 ],
#        [0.26661854],
#        [0.29757031]])

# %%
sns.histplot(k, kde=True,)
# Out:
# <Axes: ylabel='Count'>

# %%
k.reshape(1,2919)
# Out:
# array([[0.31888227, 0.32307142, 0.2932314 , ..., 0.2575128 , 0.26661854,
#         0.29757031]])
