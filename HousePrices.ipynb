# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.model_selection import GridSearchCV
pd.set_option('display.max_columns', None)

# %%
test = pd.read_csv("test.csv")
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train = pd.read_csv("train.csv")
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
t = all_data.isna().sum()
t[t.isin([0]) == False]
# Out:
# Series([], dtype: int64)

# %%
from sklearn.preprocessing import MinMaxScaler

def norm_scale_data(cul):
    t = cul
    if(t.min() > 0):
        t = stats.boxcox(cul)[0]
    t = np.array(t).reshape(-1, 1)
    mms = MinMaxScaler()
    t = mms.fit_transform(t)
    return pd.Series(t.reshape(2919), index=cul.index)
    
to_dum = ["MSZoning", "Street", ]

# %%
all_data = pd.concat([test, train])
y = all_data["SalePrice"]
all_data = all_data.drop(["Id", 'SalePrice'], axis=1)
all_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
all_data["MSSubClass"] = all_data["MSSubClass"].astype('category').cat.codes

all_data["LotFrontage"] = all_data["LotFrontage"].fillna(69)

all_data["Alley"] = all_data["Alley"].fillna("NoAccess")

to_cat_cul = ["OverallQual", "OverallCond"]
all_data[to_cat_cul] = all_data[to_cat_cul].astype("str")

all_data[["MasVnrArea", 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
           'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt']] = all_data[["MasVnrArea", 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
           'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt']].fillna(0)
all_data[['GarageCars']] = all_data[['GarageCars']].fillna(1)
all_data[['GarageArea']] = all_data[['GarageArea']].fillna(all_data["GarageArea"].mean())

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_cul = all_data.select_dtypes(include=numerics)

for i in num_cul:
    all_data[i] = norm_scale_data(all_data[i])
    
all_data["MSZoning"] = all_data["MSZoning"].fillna("RL")
all_data["Utilities"] = all_data["Utilities"].fillna("AllPub")
all_data[['Exterior1st', 'Exterior2nd']] = all_data[['Exterior1st', 'Exterior2nd']].fillna("Other")
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data[['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
          'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
          'PoolQC', 'Fence', 'MiscFeature']] = all_data[['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
          'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
          'PoolQC', 'Fence', 'MiscFeature']].fillna("NA")
all_data["Electrical"] = all_data["Electrical"].fillna("SBrkr")
all_data["KitchenQual"] = all_data["KitchenQual"].fillna("TA")
all_data["Functional"] = all_data["Functional"].fillna("Typ")
all_data["SaleType"] = all_data["SaleType"].fillna("Oth")

print(all_data.shape)

to_cat_codes = ['Neighborhood', 'Condition1', 'Condition2', 'OverallQual', 'OverallCond',
                'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'BsmtQual',
                'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC',
                'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageQual',
                'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleCondition']
cat_code_data = all_data[to_cat_codes]
all_data = all_data.drop(to_cat_codes, axis=1)

print(all_data.shape)

all_data = pd.get_dummies(all_data)

print(all_data.shape)

for i in to_cat_codes:
    all_data[i] = cat_code_data[i].astype('category').cat.codes

print(all_data.shape)
# Out:
# (2919, 79)
# (2919, 54)
# (2919, 128)
# (2919, 153)
# c:\Users\Perfomo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# c:\Users\Perfomo\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:2417: RuntimeWarning: invalid value encountered in scalar multiply
#   tmp2 = (x - v) * (fx - fw)
# c:\Users\Perfomo\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:935: RuntimeWarning: divide by zero encountered in log
#   return (lmb - 1) * np.sum(logdata, axis=0) - N/2 * np.log(variance)
# c:\Users\Perfomo\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_optimize.py:2416: RuntimeWarning: invalid value encountered in scalar subtract
#   tmp1 = (x - w) * (fx - fv)
# ...

# %%
print(all_data.shape)
# Out:
# (2919, 79)

# %%
all_data.isna().sum()
# Out:
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# YearBuilt        0
# YearRemodAdd     0
#                 ..
# GarageCond       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleCondition    0
# Length: 153, dtype: int64

# %%
all_data['GarageYrBlt'].isna().sum()
# Out:
# 159

# %%
test_data = all_data.iloc[0:1459]
test_data
# Out:
#       MSSubClass  LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0              0     0.318882  0.349340   0.469551      0.112279     0.00000
# 1              0     0.323071  0.387426   0.445216      0.079388     0.06750
# 2              5     0.293231  0.381582   0.831463      0.705944     0.00000
# 3              5     0.310432  0.321664   0.843624      0.705944     0.01250
# 4             11     0.141947  0.203099   0.772548      0.580937     0.00000
# ...          ...          ...       ...        ...           ...         ...
# 1454          13     0.000000  0.056341   0.547444      0.222453     0.00000
# 1455          13     0.000000  0.053162   0.547444      0.222453     0.00000
# 1456           0     0.602101  0.452423   0.461352      0.662774     0.00000
# 1457           9     0.238917  0.329837   0.772548      0.580937     0.00000
# 1458           5     0.293231  0.315244   0.784083      0.621122     0.05875
#
# ...

# %%
train_data = all_data.iloc[1459::]
train_data
# Out:
#       MSSubClass  LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0              5     0.252913  0.292120   0.906390      0.820872    0.122500
# 1              0     0.318882  0.314742   0.603702      0.306560    0.000000
# 2              5     0.266619  0.343391   0.880886      0.797058    0.101250
# 3              6     0.229416  0.313809   0.170917      0.222453    0.000000
# 4              5     0.335500  0.387333   0.868334      0.750687    0.218750
# ...          ...          ...       ...        ...           ...         ...
# 1455           5     0.238917  0.280712   0.855914      0.750687    0.000000
# 1456           0     0.339598  0.372515   0.623270      0.504767    0.074375
# 1457           6     0.257513  0.304078   0.321256      0.894915    0.000000
# 1458           0     0.266619  0.316909   0.384040      0.662774    0.000000
# 1459           0     0.297570  0.320924   0.503244      0.159027    0.000000
#
# ...

# %%
y = y.iloc[1459::]
y
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1460, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_data, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(n_estimators=105, learning_rate=0.05, max_depth=5, random_state=0)

# %%
xgb_parameters = {
    'n_estimators': [300, 500, 600],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.05, 0.01, 0.1, 0.15],
}

# %%
xgbr_search = GridSearchCV(gb, xgb_parameters, cv=5, scoring='neg_mean_squared_error')
xgbr_search.fit(train_data, y)
best_model = xgbr_search.best_estimator_

# %%
best_model.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.05,
#  'loss': 'squared_error',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 600,
#  'n_iter_no_change': None,
#  'random_state': 0,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
prediction = best_model.predict(test_data)

# %%
prediction
# Out:
# array([128526.13292962, 166591.94564908, 184586.66314064, ...,
#        156934.80151836, 108528.39967014, 226310.74142497])

# %%
result = pd.read_csv("sample_submission.csv")
result["SalePrice"] = prediction

# %%
result.to_csv("result.csv", index=False)
